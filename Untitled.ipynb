# %%
from google_trans_new import google_translator

translator = google_translator()
translate_text = translator.translate("Hola!", lang_src="es", lang_tgt="en")
print(translate_text)
# Out:
# /usr/lib/python3/dist-packages/requests/__init__.py:89: RequestsDependencyWarning: urllib3 (1.26.7) or chardet (3.0.4) doesn't match a supported version!
#   warnings.warn("urllib3 ({}) or chardet ({}) doesn't match a supported "
# ---------------------------------------------------------------------------
# JSONDecodeError                           Traceback (most recent call last)
# <ipython-input-1-a98180178f1e> in <module>
#       2
#       3 translator = google_translator()
# ----> 4 translate_text = translator.translate("Hola!", lang_src="es", lang_tgt="en")
#       5 print(translate_text)
#
# ~/.local/lib/python3.8/site-packages/google_trans_new/google_trans_new.py in translate(self, text, lang_tgt, lang_src, pronounce)
#     186                                 return [sentences, pronounce_src, pronounce_tgt]
#     187                     except Exception as e:
# --> 188                         raise e
#     189             r.raise_for_status()
# ...

# %%
import googletrans
from googletrans import *
translator = googletrans.Translator()

my_eng = translator.translate("Die Umsatzsteuervoranmeldungsstatistik umfasst Monats- , Quartals- und Jahresergebnisse, die jeweils am Beginn des drittfolgenden Monats als vorläufige, ein Monat danach als endgültige Ergebnisse publiziert werden. Der Zweck der Umsatzsteuervoranmeldung besteht in der laufenden Entrichtung der Umsatzsteuer, indem jeweils für den sogenannten Voranmeldungszeitraum – ein Monat oder ein Quartal – die Umsatzsteuer für die in diesem Zeitraum angefallenen Umsätze abzüglich der Vorsteuer berechnet und im Fall einer Zahllast an die Finanzverwaltung abgeführt wird. Dabei handelt es sich um Umsatzsteuer-Vorauszahlungen; die endgültige Umsatzsteuer für ein Kalenderjahr wird dann auf Basis der Umsatzsteuererklärung für dieses Jahr durch den daraus resultierenden Umsatzsteuerbescheid festgelegt. Umsatzsteuerpflichtig sind die Lieferungen und sonstigen Leistungen, die ein Unternehmen im Inland gegen Entgelt durchführt, der Eigenverbrauch und die Einfuhr von Gegenständen.", dest="en")

# %%
my_eng.text
# Out:
# 'The sales tax pre-registration statistics include month, quarterly and annual results, which are published as a final results one month after the beginning of the third month.The purpose of the sales tax advance registration consists in the ongoing payment of the sales tax, in which the sales tax for the sales incurred during this period is calculated for the so -called pre -registration period - one month or a quarter - is paid to the financial administration in the event of a number burden.These are sales tax advance payments;The final sales tax for a calendar year is then determined on the basis of the sales tax return for this year by the resulting VAT notice.The deliveries and other services that a company conducts in Germany against fee are subject to VAT and the import of objects.'

# %%
body > app-root > lib-dynamic-menu > mat-sidenav-container > mat-sidenav-content > lib-main > div > div > div > form > lib-product-list > div.product-list > div:nth-child(1) > mat-card > mat-card-title > h3

# %%
body > app-root > lib-dynamic-menu > mat-sidenav-container > mat-sidenav-content > lib-main > div > div > div > form > lib-product-list > div.product-list > div:nth-child(1) > mat-card > mat-card-content > p.col.col-2 > span:nth-child(2)

# %%
import googletrans
from googletrans import *

import json
import os

from selenium import webdriver
import geckodriver_autoinstaller

from selenium.webdriver.common.keys import Keys
from selenium.webdriver.common.desired_capabilities import DesiredCapabilities

import time

geckodriver_autoinstaller.install()
#PATH = "/home/majid/dev/selenium/"

translator = googletrans.Translator()
# /home/majid/.mozilla/firefox/qtgamvz4.default-release
profile = webdriver.FirefoxProfile(
    '/home/majid/.mozilla/firefox/qtgamvz4.default-release')

profile.set_preference("dom.webdriver.enabled", False)
profile.set_preference('useAutomationExtension', False)
profile.update_preferences()
desired = DesiredCapabilities.FIREFOX

driver = webdriver.Firefox(firefox_profile=profile,
                           desired_capabilities=desired)
driver.get("https://www.statistik.at/amdc-data/#/product")
driver.implicitly_wait(10)

mother_dic = {}
for i in range(1, 53):
    inner_dic = {}
    
    good_heading = driver.find_element_by_css_selector(f'body > app-root > lib-dynamic-menu > mat-sidenav-container > mat-sidenav-content > lib-main > div > div > div > form > lib-product-list > div.product-list > div:nth-child({i}) > mat-card > mat-card-title > h3')
    my_ger_heading = good_heading.get_attribute('innerHTML')
    my_eng_heading = translator.translate(my_ger_heading, dest="en")
    inner_dic["heading"] = my_eng_heading.text
    
    good_themes = driver.find_element_by_css_selector(f'body > app-root > lib-dynamic-menu > mat-sidenav-container > mat-sidenav-content > lib-main > div > div > div > form > lib-product-list > div.product-list > div:nth-child({i}) > mat-card > mat-card-content > p.col.col-1 > span:nth-child(2)')
    my_ger_theme = good_themes.get_attribute('innerHTML')
    my_eng_theme = translator.translate(my_ger_theme, dest="en")
    inner_dic["themes"] = my_eng_theme.text
    
    good_years = driver.find_element_by_css_selector(f'body > app-root > lib-dynamic-menu > mat-sidenav-container > mat-sidenav-content > lib-main > div > div > div > form > lib-product-list > div.product-list > div:nth-child({i}) > mat-card > mat-card-content > p.col.col-2 > span:nth-child(2)')
    my_year = good_years.get_attribute('innerHTML')
    inner_dic["years"] = my_year
    
    mother_dic[str(i)] = inner_dic

my_local_address = "/home/majid/dev/scraper_seshat/peter/"
if not os.path.exists(my_local_address):
    os.makedirs(my_local_address)
my_file= my_local_address + "themes_for_peter.json"
with open(my_file, "w") as myjsonfile:
    json.dump(mother_dic, myjsonfile)    
    #print(my_eng.text)
# Out:
# <ipython-input-13-c9d1fe4d5e1c>:20: DeprecationWarning: firefox_profile has been deprecated, please use an Options object
#   profile = webdriver.FirefoxProfile(
# <ipython-input-13-c9d1fe4d5e1c>:28: DeprecationWarning: capabilities and desired_capabilities have been deprecated, please pass in a Service object
#   driver = webdriver.Firefox(firefox_profile=profile,
# <ipython-input-13-c9d1fe4d5e1c>:28: DeprecationWarning: firefox_profile has been deprecated, please pass in an Options object
#   driver = webdriver.Firefox(firefox_profile=profile,
# <ipython-input-13-c9d1fe4d5e1c>:37: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   good_heading = driver.find_element_by_css_selector(f'body > app-root > lib-dynamic-menu > mat-sidenav-container > mat-sidenav-content > lib-main > div > div > div > form > lib-product-list > div.product-list > div:nth-child({i}) > mat-card > mat-card-title > h3')
# ...

# %%
import googletrans
from googletrans import *

import json
import os

from selenium import webdriver
import geckodriver_autoinstaller

from selenium.webdriver.common.keys import Keys
from selenium.webdriver.common.desired_capabilities import DesiredCapabilities

import time

geckodriver_autoinstaller.install()
#PATH = "/home/majid/dev/selenium/"

translator = googletrans.Translator()
# /home/majid/.mozilla/firefox/qtgamvz4.default-release
profile = webdriver.FirefoxProfile(
    '/home/majid/.mozilla/firefox/qtgamvz4.default-release')

profile.set_preference("dom.webdriver.enabled", False)
profile.set_preference('useAutomationExtension', False)
profile.update_preferences()
desired = DesiredCapabilities.FIREFOX

driver = webdriver.Firefox(firefox_profile=profile,
                           desired_capabilities=desired)

driver.get("https://www.statistik.at/amdc-data/#/product")
driver.implicitly_wait(10)

my_errors = []
mother_dic_2 = {}
for i in range(28, 53):
    inner_dic = {}
    
    good_heading = driver.find_element_by_css_selector(f'body > app-root > lib-dynamic-menu > mat-sidenav-container > mat-sidenav-content > lib-main > div > div > div > form > lib-product-list > div.product-list > div:nth-child({i}) > mat-card > mat-card-title > h3')
    my_ger_heading = good_heading.get_attribute('innerHTML')
    try:
        my_eng_heading = translator.translate(my_ger_heading, dest="en")
        inner_dic["heading"] = my_eng_heading.text
    except:
        inner_dic["heading"] = "No Translations Provided."
    
    good_themes = driver.find_element_by_css_selector(f'body > app-root > lib-dynamic-menu > mat-sidenav-container > mat-sidenav-content > lib-main > div > div > div > form > lib-product-list > div.product-list > div:nth-child({i}) > mat-card > mat-card-content > p.col.col-1 > span:nth-child(2)')
    my_ger_theme = good_themes.get_attribute('innerHTML')
    try:
        my_eng_theme = translator.translate(my_ger_theme, dest="en")
        inner_dic["themes"] = my_eng_theme.text
    except:
        inner_dic["themes"] = "No Translations Provided."
    
    good_years = driver.find_element_by_css_selector(f'body > app-root > lib-dynamic-menu > mat-sidenav-container > mat-sidenav-content > lib-main > div > div > div > form > lib-product-list > div.product-list > div:nth-child({i}) > mat-card > mat-card-content > p.col.col-2 > span:nth-child(2)')
    my_year = good_years.get_attribute('innerHTML')
    inner_dic["years"] = my_year
    
    # let'S get deeper
    
    good_heading_button = driver.find_element_by_css_selector(f'body > app-root > lib-dynamic-menu > mat-sidenav-container > mat-sidenav-content > lib-main > div > div > div > form > lib-product-list > div.product-list > div:nth-child({i}) > mat-card > mat-card-title > h3')
    good_heading_button.click()
    time.sleep(5)
    # description 
    #cdk-accordion-child-1 > div > div > div:nth-child(4) > span.key
    desc_element_key = driver.find_element_by_css_selector(f'#cdk-accordion-child-1 > div > div > div:nth-child(4) > span.key')
    if desc_element_key.get_attribute('innerHTML') == "Kurzbeschreibung:":
        desc_element_value_ger = driver.find_element_by_css_selector(f'#cdk-accordion-child-1 > div > div > div:nth-child(4) > span.value')
        my_ger_desc = desc_element_value_ger.get_attribute('innerHTML')
        try:
            my_eng_desc = translator.translate(my_ger_desc, dest="en")
            inner_dic["short_description"] = my_eng_desc.text
        except:
            inner_dic["short_description"] = "No Translations Provided."
    else:
        inner_dic["short_description"] = "No description found."
        print("No Description for: ", my_eng_heading)
    # expanding vars
    expand_button = driver.find_element_by_css_selector(f'body > app-root > lib-dynamic-menu > mat-sidenav-container > mat-sidenav-content > lib-main > div > div > div > lib-product > mat-card > mat-card-content > form > div > div.txt-align-right > button:nth-child(1) > span.mat-button-wrapper')
    try:
        expand_button.click()
    except:
        error_message = f"No Clickable button for item: {i}, {good_heading}."
        my_errors.append(error_message)
    time.sleep(3)
        
    # read the number of groups:
    
    title_bottom = driver.find_element_by_css_selector('body > app-root > lib-dynamic-menu > mat-sidenav-container > mat-sidenav-content > lib-main > div > div > div > lib-product > mat-card > mat-card-header > div > mat-card-title > h3')
    full_str = title_bottom.get_attribute('innerHTML')
    stripped_str = full_str.strip()
    good_number = stripped_str.split(" ")[0]
    good_number2 = stripped_str.split(" ")[-2]
    good_number_int = int(good_number)
    good_number_int2 = int(good_number2)

    variable_list = []
    for j in range(4, 4+good_number_int):
        for jj in range(1, good_number_int2 + 1):
            try:
                list_item = driver.find_element_by_css_selector(f'#cdk-accordion-child-{j} > div > div > div:nth-child({jj}) > div > div.produkt-wk-name > span')
                my_ger_li = list_item.get_attribute('innerHTML')
                my_eng_li = translator.translate(my_ger_li, dest="en")
                variable_list.append(my_eng_li.text)
                #print("Hallo")
            except:
                #print("CIAOoooooo")
                break
    inner_dic["variable_list"] = variable_list
    mother_dic_2[str(i)] = inner_dic
    print(str(i))
    
    #title_bottom = driver.find_element_by_css_selector('body > app-root > lib-dynamic-menu > mat-sidenav-container > mat-sidenav-content > lib-main > div > div > div > lib-product > mat-card > mat-card-header > div > mat-card-title > h3')
    #title_bottom.sendKeys(Keys.F5)
    driver.execute_script("location.reload(true);")
    time.sleep(5)

my_local_address = "/home/majid/dev/scraper_seshat/peter/"
if not os.path.exists(my_local_address):
    os.makedirs(my_local_address)
my_file= my_local_address + "themes_for_peter_full_2.json"
with open(my_file, "w") as myjsonfile:
    json.dump(mother_dic_2, myjsonfile)    
    #print(my_eng.text)
# Out:
# <ipython-input-38-e3d38aa641f7>:20: DeprecationWarning: firefox_profile has been deprecated, please use an Options object
#   profile = webdriver.FirefoxProfile(
# <ipython-input-38-e3d38aa641f7>:28: DeprecationWarning: capabilities and desired_capabilities have been deprecated, please pass in a Service object
#   driver = webdriver.Firefox(firefox_profile=profile,
# <ipython-input-38-e3d38aa641f7>:28: DeprecationWarning: firefox_profile has been deprecated, please pass in an Options object
#   driver = webdriver.Firefox(firefox_profile=profile,
# <ipython-input-38-e3d38aa641f7>:39: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   good_heading = driver.find_element_by_css_selector(f'body > app-root > lib-dynamic-menu > mat-sidenav-container > mat-sidenav-content > lib-main > div > div > div > form > lib-product-list > div.product-list > div:nth-child({i}) > mat-card > mat-card-title > h3')
# ...

# %%
len(mother_dic)
# Out:
# 27

# %%
my_local_address = "/home/majid/dev/scraper_seshat/peter/"
if not os.path.exists(my_local_address):
    os.makedirs(my_local_address)
my_file= my_local_address + "themes_for_peter_full_1.json"
with open(my_file, "w") as myjsonfile:
    json.dump(mother_dic, myjsonfile)

# %%
mother_dic["21"]
# Out:
# {'heading': 'University statistics',
#  'themes': 'University, students, studies, university',
#  'years': '2003, 2004, 2005, 2006, 2007, 2008, 2009, 2010, 2011, 2012, 2013, 2014, 2015, 2016, 2017, 2018, 2019, 2020, 2021',
#  'short_description': 'Based on the Education Documentation Act, the university statistics provide data on students, degrees and teaching staff at the Austrian universities.',
#  'variable_list': ['Based on the Education Documentation Act, the university statistics provide data on students, degrees and teaching staff at the Austrian universities.',
#   'Based on the Education Documentation Act, the university statistics provide data on students, degrees and teaching staff at the Austrian universities.',
#   'Based on the Education Documentation Act, the university statistics provide data on students, degrees and teaching staff at the Austrian universities.',
# ...

# %%
import xlwt

# %%
def output_xlsx(filename, sheet, list1, list2, list3):
    book = xlwt.Workbook()
    sh = book.add_sheet(sheet)

    col1_name = 'Header'
    col2_name = 'Themes'
    col3_name = 'Explanation'
    for n, (v_desc, v) in enumerate(zip(desc, variables)):
        sh.write(n, 0, v_desc)
        sh.write(n, 1, v)    
    n+=1

    sh.write(n, 0, col1_name)
    sh.write(n, 1, col2_name)
    sh.write(n, 2, col3_name)

    for m, e1 in enumerate(list1):
        sh.write(m, 0, e1)

    for m, e2 in enumerate(list2):
        sh.write(m, 1, e2)

    book.save(filename)

# %%
output_xlsx("majidian.xlsx", "shit", ["abc", "sdf", "rtz"] ,["abuc", "sd8f", "rt9z"],["abghhhuc", "sdhhhh8f", "rthhh9z"],)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-60-4a3db754143b> in <module>
# ----> 1 output_xlsx("majidian.xlsx", "shit", ["abc", "sdf", "rtz"] ,["abuc", "sd8f", "rt9z"],["abghhhuc", "sdhhhh8f", "rthhh9z"],)
#
# <ipython-input-59-1f2aa652963a> in output_xlsx(filename, sheet, list1, list2, list3)
#       6     col2_name = 'Themes'
#       7     col3_name = 'Explanation'
# ----> 8     for n, (v_desc, v) in enumerate(zip(desc, variables)):
#       9         sh.write(n, 0, v_desc)
#      10         sh.write(n, 1, v)
#
# NameError: name 'desc' is not defined

# %%
"majidian.xlsx", "shit"

# %%
import csv
import json

my_json_file = "/home/majid/dev/scraper_seshat/peter/themes_for_peter_all.json"
with open(my_json_file, "r") as json_file:
    data = json.load(json_file)
    my_csv_file = "/home/majid/dev/scraper_seshat/peter/themes_for_peter_all_csv.csv"
    with open(my_csv_file, "w") as my_csv_write_file:
        first_line = ["Header", "Theme", "Description"]
        writer = csv.writer(my_csv_write_file, delimiter ="|")
        writer.writerow(first_line)
        one_line=[]
        for key in data.keys():
            one_line=[]
            my_heading = data[key].get("heading")
            my_heading_better = my_heading.replace("\"", "")
            my_heading_better = my_heading_better.replace("\n", "")
            my_themes = data[key].get("themes")
            my_themes_better = my_themes.replace("\"", "")
            my_themes_better = my_themes_better.replace("\n", "")
            my_description = data[key].get("short_description")
            my_description_better = my_description.replace("\"", "")
            my_description_better = my_description_better.replace("\n", "")
            one_line.append(my_heading_better)
            one_line.append(my_themes_better)
            one_line.append(my_description_better)
            
            #one_line_str = "|".join(one_line)
            print(one_line)
            writer.writerow(one_line)
    print(len(data))
# Out:
# ['AES 2016/17 - survey on adult education 2016/17', 'Training, adult education, courses, lifelong learning, further education', 'Survey on learning and educational activities of the Austrian resident population aged 25 to 64 years within a period of twelve months;There are a total of 5,620 people who are very calculated 4.8 million inhabitants: represent Austria on the inside.']
# ['AEST regz - coordinated employment statistics and register counting', 'Workplaces, workplates, employees, education, census, demographic characteristics, acquisition characteristics, families, buildings, building and housing counts, households, regional features, companies, census, apartments, census', 'The coordinated acquisition statistics and register count receives data about: persons and employment statistics from 2008, education and commuting from 2009, families and households from 2011, Occupational facilities from 2011, building and apartment count 2011']
# ...

# %%
xyz = 'ALi nnn" rr'

# %%
sdss = xyz.replace("\"", "")

# %%
sdss
# Out:
# 'ALi nnn rr'

# %%
import csv
import json

my_json_file = "/home/majid/dev/scraper_seshat/peter/themes_for_peter_all.json"
with open(my_json_file, "r") as json_file:
    data = json.load(json_file)
    my_csv_file = "/home/majid/dev/scraper_seshat/peter/themes_for_peter_all_csv_all_vars.csv"
    with open(my_csv_file, "w") as my_csv_write_file:
        first_line = ["Header", "Theme", "Variables"]
        writer = csv.writer(my_csv_write_file, delimiter ="|")
        writer.writerow(first_line)
        one_line=[]
        for key in data.keys():
            my_heading = data[key].get("heading")
            my_heading_better = my_heading.replace("\"", "")
            my_heading_better = my_heading_better.replace("\n", "")
            my_themes = data[key].get("themes")
            my_themes_better = my_themes.replace("\"", "")
            my_themes_better = my_themes_better.replace("\n", "")
            my_vars = data[key].get("variable_list")
            for item in my_vars:
                one_line=[]
                one_line.append(my_heading_better)
                one_line.append(my_themes_better)
                my_var_better = item.replace("\"", "")
                my_var_better = my_var_better.replace("\n", "")
                one_line.append(my_var_better)
                writer.writerow(one_line)
            
            #one_line_str = "|".join(one_line)
            #print(one_line)
            #writer.writerow(one_line)
    print(len(data))
# Out:
# 52
